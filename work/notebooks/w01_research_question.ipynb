# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/nourhussien10/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ## My lane
#
# I chose **Lane 2: Refresh / Content Opportunity Scoring**.
#
# I chose this lane because it focuses on helping content teams decide which pages should be reviewed first. This is a practical business problem, and the starter dataset contains page performance information that can help prioritize review instead of checking every page manually.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ## Research Question
#
# **Decision:** Decide which pages should be reviewed first.
#
# **Unit of analysis:** One content page.
#
# **Output:** A ranked list of pages that should be refreshed or monitored.
#
# **Action:** The content team reviews and updates the highest priority pages.
#
# **Cost of a wrong recommendation:** If an important page is missed, traffic opportunities may be lost. If a healthy page is selected by mistake, the team spends time unnecessarily.
#
# **Why ML or data analysis helps:** The dataset contains many pages, so data analysis or machine learning can help prioritize them more efficiently than reviewing every page manually.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# ## Quick look at the data
#
# The starter dataset contains **30,000 rows** and **44 columns**.
#
# The average search volume is about **158.88**, while the average competition score is about **0.147**.
#
# These numbers show that the dataset contains enough pages and useful SEO metrics to prioritize which pages should be reviewed first.

# %%
import pandas as pd

df = pd.read_csv("/content/flyrank-ml-internship/data/raw/content_refresh_anonymized.csv")

print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
print(df.describe(include="all"))
# Out:
# Rows: 30000
# Columns: 44
#                   content_id          client_id  search_volume   competition  \
# count                  30000              30000   27532.000000  27532.000000
# unique                 30000                 32            NaN           NaN
# top     content_6880eb215048  client_19581e27de            NaN           NaN
# freq                       1               7008            NaN           NaN
# mean                     NaN                NaN     158.882391      0.146954
# std                      NaN                NaN    1518.270825      0.285241
# min                      NaN                NaN       0.000000      0.000000
# 25%                      NaN                NaN       0.000000      0.000000
# 50%                      NaN                NaN      10.000000      0.000000
# 75%                      NaN                NaN      20.000000      0.130000
# max                      NaN                NaN   74000.000000      1.000000
#
# ...

# %% [markdown]
# ## Careful words
#
# This work can identify patterns and help prioritize pages for review based on the available data.
#
# It cannot prove that one factor causes another, and it cannot guarantee future performance. The recommendations should support human decisions rather than replace them.

# %%
# !git clone https://github.com/nourhussien10/flyrank-ml-internship.git
# Out:
# fatal: destination path 'flyrank-ml-internship' already exists and is not an empty directory.

# %%
import os
os.listdir("/content/flyrank-ml-internship/data/raw")
# Out:
# ['content_refresh_anonymized.csv']

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
