# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/nourhussien10/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## My lane as an ML task
#
# **Task type:** Ranking
#
# This lane is a ranking task because the goal is to prioritize content pages based on how urgently they should be reviewed or refreshed. The output is an ordered list of pages rather than a simple yes/no decision.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Target or proxy
#
# **Target:** A refresh priority score for each content page.
#
# **Proxy:** The score is estimated using available page signals such as traffic, CTR, search volume, and other content performance features.
#
# The target is based on observed data rather than a manually defined rule, allowing the model to learn patterns from the dataset.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Success metric
#
# **Metric:** Precision@10
#
# The model is successful if most of the top 10 recommended pages truly need to be refreshed. This helps the content team focus on the highest priority pages first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## The unit of analysis
#
# Each row in the dataframe represents one content page.
#
# The features describe the page, such as traffic, CTR, search volume, competition, word count, and other content metrics. These features are used to estimate the page's refresh priority.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Why ML beats a fixed rule
#
# A fixed rule cannot capture the complex relationship between multiple content signals. Machine learning can learn patterns from historical data and combine many features to produce better page rankings than a single manually written rule.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
